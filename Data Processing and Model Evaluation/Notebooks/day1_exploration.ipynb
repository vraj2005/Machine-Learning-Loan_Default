# %% [markdown]
# # Day 1 – Dataset Exploration
# This notebook covers dataset loading, shape analysis, column inspection, and class distribution.

# %%
import pandas as pd

# Load dataset (update path accordingly)
# df = pd.read_csv("../Dataset/Loan_default.csv")

# Basic exploration
# df.head()
# df.shape
# df.info()
# df.describe()

# Columns
# df.columns

# Class distribution
# df['Default'].value_counts()
